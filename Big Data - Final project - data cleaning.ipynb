# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('newdata.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41029 entries, 0 to 41028
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   fraud_bool                        41029 non-null  int64
#  1   income                            41029 non-null  float64
#  2   name_email_similarity             41029 non-null  float64
#  3   prev_address_months_count         41029 non-null  int64
#  4   current_address_months_count      41029 non-null  int64
#  5   customer_age                      41029 non-null  int64
#  6   days_since_request                41029 non-null  float64
#  7   intended_balcon_amount            41029 non-null  float64
#  8   payment_type                      41029 non-null  object
#  9   zip_count_4w                      41029 non-null  int64
#  10  velocity_6h                       41029 non-null  float64
#  11  velocity_24h                      41029 non-null  float64
#  12  velocity_4w                       41029 non-null  float64
#  13  bank_branch_count_8w              41029 non-null  int64
#  14  date_of_birth_distinct_emails_4w  41029 non-null  int64
#  15  employment_status                 41029 non-null  object
#  16  credit_risk_score                 41029 non-null  int64
#  17  email_is_free                     41029 non-null  int64
#  18  housing_status                    41029 non-null  object
#  19  phone_home_valid                  41029 non-null  int64
#  20  phone_mobile_valid                41029 non-null  int64
#  21  bank_months_count                 41029 non-null  int64
#  22  has_other_cards                   41029 non-null  int64
#  23  proposed_credit_limit             41029 non-null  int64
#  24  foreign_request                   41029 non-null  int64
#  25  source                            41029 non-null  object
#  26  session_length_in_minutes         41029 non-null  float64
#  27  device_os                         41029 non-null  object
#  28  keep_alive_session                41029 non-null  int64
#  29  device_distinct_emails_8w         41029 non-null  int64
#  30  device_fraud_count                41029 non-null  int64
#  31  month                             41029 non-null  int64
# dtypes: float64(8), int64(19), object(5)
# memory usage: 10.0+ MB

# %%
df.describe()
# Out:
#        name_email_similarity  prev_address_months_count  \
# count           41029.000000               41029.000000
# mean                0.467517                  13.859709
# std                 0.294399                  41.502432
# min                 0.000042                  -1.000000
# 25%                 0.189494                  -1.000000
# 50%                 0.454523                  -1.000000
# 75%                 0.740348                  -1.000000
# max                 0.999997                 377.000000
#
#        current_address_months_count  days_since_request  \
# count                  41029.000000        41029.000000
# mean                      93.716323            1.014534
# std                       88.220064            5.355843
# min                       -1.000000            0.000001
# 25%                       28.000000            0.006797
# 50%                       63.000000            0.014583
# 75%                      139.000000            0.025591
# max                      410.000000           75.495921
#
#        intended_balcon_amount  zip_count_4w   velocity_6h  velocity_24h  \
# count            41029.000000  41029.000000  41029.000000  41029.000000
# mean                 7.354056   1583.621292   5540.921437   4726.906808
# std                 19.216247   1009.837964   2989.728395   1471.214586
# min                -14.383932      9.000000     41.990963   1324.786832
# 25%                 -1.183513    894.000000   3305.221458   3545.919784
# 50%                 -0.856725   1274.000000   5209.802000   4722.554151
# 75%                 -0.334787   1974.000000   7548.774146   5704.778806
# max                111.659817   6381.000000  16192.044925   9393.013600
#
#         velocity_4w  bank_branch_count_8w  date_of_birth_distinct_emails_4w  \
# count  41029.000000          41029.000000                      41029.000000
# mean    4825.974185            168.169417                          8.961271
# std      934.344488            445.776382                          5.083114
# min     2863.783336              0.000000                          0.000000
# 25%     4249.841958              1.000000                          5.000000
# 50%     4887.635266              8.000000                          8.000000
# 75%     5468.620435             20.000000                         12.000000
# max     6945.709990           2327.000000                         36.000000
#
#        credit_risk_score  bank_months_count  session_length_in_minutes
# count       41029.000000       41029.000000               41029.000000
# mean          143.159911          10.718199                   7.754705
# std            75.942146          12.329035                   8.572509
# min          -139.000000          -1.000000                  -1.000000
# 25%            88.000000          -1.000000                   3.131975
# 50%           133.000000           4.000000                   5.100772
# 75%           196.000000          25.000000                   8.838050
# max           378.000000          32.000000                  82.004731

# %%
df.shape
# Out:
# (41029, 32)

# %%
correlation_matrix = df.corr()

plt.figure(figsize=(20, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# /var/folders/kz/dhtdp71n1q98lc7x715t7c0h0000gp/T/ipykernel_7978/3897820917.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
df['fraud_bool'] = df['fraud_bool'].astype(str)
df = df.apply(lambda x: x.astype(str) if x.nunique() < 15 else x)
